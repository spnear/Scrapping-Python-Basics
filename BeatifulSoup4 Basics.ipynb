# %% [markdown]
# ### BeatifulSoup
#
# Librería utilizada para manipular el documento HTML, convierte el documento en una estructura para manipular con queries

# %%
import bs4
import requests

# %%
url = 'https://www.platzi.com'
response = requests.get(url)
response.encoding ='utf-8'

# %%
soup = bs4.BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.title.text)
# Out:
# Platzi: ‎Cursos Online Profesionales de Tecnología

# %%
print(soup.select('meta[name=description]'))
# Out:
# [<meta content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!" name="description"/>]

# %%
print(soup.select('meta[name=description]')[0]['content'])
# Out:
# Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!

# %%
courses_link = soup.select('.SchoolsList-school')
courses = [course['href'] for course in courses_link]

for course in courses:
    print(course)
# Out:
# /web/
# /escuela-javascript/
# /idioma-ingles/
# /marketing-digital/
# /startups/
# /publicidad/
# /diseno-producto/
# /periodismo-digital/
# /videojuegos/
# /negocios/
# /ecommerce/
# /finanzas/
# /azure/
# /diseno-grafico/
# /datos/
# /produccion-video/
# /matematicas/
# /blockchain-criptomonedas/
# /software/
# /habilidades-blandas/

# %% [markdown]
# #### Reto personal:
#
# Hago un scrapping sencillo con lo aprendido con la página web de un periódico local (La nación - Neiva)
# Extraigo la lista de noticias y seguido extraigo datos de un artículo

# %%
url = "https://www.lanacion.com.co/"

response = requests.get(url)

soup = bs4.BeautifulSoup(response.text, 'html.parser')
news = soup.select('.penci_media_object a')

for item in news:
    print(f"Noticia: {item.text} | Link: {url}{item['href']}")
    print()
# Out:
# Noticia:  | Link: https://www.lanacion.com.co/https://www.lanacion.com.co/las-nuevas-tecnologias-llegaron-para-quedarse-en-el-deporte/
#
# Noticia: Las nuevas tecnologías llegaron para quedarse en el deporte | Link: https://www.lanacion.com.co/https://www.lanacion.com.co/las-nuevas-tecnologias-llegaron-para-quedarse-en-el-deporte/
#
# Noticia: Redacción Web // LN | Link: https://www.lanacion.com.co/https://www.lanacion.com.co/author/prensaweb/
#
# Noticia:  | Link: https://www.lanacion.com.co/https://www.lanacion.com.co/neiva-empieza-a-brillar-con-luz-propia/
#
# Noticia: “Neiva empieza a brillar con luz propia” | Link: https://www.lanacion.com.co/https://www.lanacion.com.co/neiva-empieza-a-brillar-con-luz-propia/
#
# Noticia: Andrea Beltrán Cruz | Link: https://www.lanacion.com.co/https://www.lanacion.com.co/author/web2/
#
# Noticia:  | Link: https://www.lanacion.com.co/https://www.lanacion.com.co/detenido-por-trafico-de-estupefacientes/
#
# ...

# %%
url = "https://www.lanacion.com.co/huila-registro-17-muertes-por-covid-19-2/"

response = requests.get(url)

soup = bs4.BeautifulSoup(response.text, 'html.parser')
paragraphs = soup.select('.penci-container p')

#print(soup)
for idx,item in enumerate(paragraphs):
    print(f"Párrafo No{idx}, texto: \n{item.text}\n")
    print(item)
# Out:
# Párrafo No0, texto:
# El Ministerio de Salud reportó que en el Huila se registraron ayer 168 casos nuevos de personas contagiadas de COVID-19 y la muerte de 17 pacientes. Neiva sigue siendo el municipio con el mayor número de muertes diarias a causa del coronavirus.
#
# <p style="text-align: center;"><strong>El Ministerio de Salud reportó que en el Huila se registraron ayer 168 casos nuevos de personas contagiadas de COVID-19 y la muerte de 17 pacientes. Neiva sigue siendo el municipio con el mayor número de muertes diarias a causa del coronavirus.</strong></p>
# Párrafo No1, texto:
# Neiva sigue siendo el municipio huilense con el mayor número de personas fallecidas y contagiadas diariamente a causa del COVID-19.
#
# <p>Neiva sigue siendo el municipio huilense con el mayor número de personas fallecidas y contagiadas diariamente a causa del COVID-19.</p>
# Párrafo No2, texto:
# ...

# %%
#Extraer título
title = soup.select('h1.penci-entry-title')
print(title[0].text)
# Out:
# Huila registró 17 muertes por COVID-19

# %%
response = requests.get('https://jkanime.net/')
soup = bs4.BeautifulSoup(response.text, 'html.parser')


animes = soup.select('.anime__sidebar__comment__item__text h5')

for idx,anime in enumerate(animes):
    print(f"No{idx+1} | texto: \n{anime.text}\n")
# Out:
# No1 | texto:
# Tensei shitara Slime Datta Ken 2nd Season Part 2
#
# No2 | texto:
# Seirei Gensouki
#
# No3 | texto:
# Deatte 5-byou de Battle
#
# No4 | texto:
# Uramichi Oniisan
#
# No5 | texto:
# Fumetsu no Anata e
#
# No6 | texto:
# Yami Shibai 9
#
# No7 | texto:
# Kingdom 3rd Season
#
# No8 | texto:
# Tantei wa Mou, Shindeiru.
#
# No9 | texto:
# Shinigami Bocchan to Kuro Maid
#
# No10 | texto:
# Getter Robo Arc
#
# No11 | texto:
# IDOLiSH7: Third Beat!
#
# No12 | texto:
# Jahy-sama wa Kujikenai!
#
# No13 | texto:
# Boruto: Naruto Next Generations
#
# No14 | texto:
# One Piece
#
# No15 | texto:
# Tropical-Rouge! Precure
#
# No16 | texto:
# Digimon Adventure 2020
#
# No17 | texto:
# Tokyo Revengers
#
# No18 | texto:
# Edens Zero
#
# No19 | texto:
# Genjitsu Shugi Yuusha no Oukoku Saikenki
#
# No20 | texto:
# Re-Main
#
# No21 | texto:
# Magia Record: Mahou Shoujo Madoka☆Magica Gaiden (TV) 2nd Season
#
# No22 | texto:
# Kageki Shoujo!!
#
# No23 | texto:
# Mahouka Koukou no Yuutousei
# ...
